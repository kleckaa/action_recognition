# %%
from Eval_loss import plot_graph_loss
from Eval_loss import plot_graph_top
from Eval_top import accuracy

# %%
path_ground_truth = 'softmax_val/test_evalu.txt'
main_path = 'softmax_val/rgb/'

path_test_file = main_path + 'test_1crops_1clips_224.csv'

top1, top3, top5 = accuracy(path_ground_truth, path_test_file)

print ('Top1: ' + str(top1*100) + ' %')
print ('Top3: ' + str(top3*100) + ' %')
print ('Top5: ' + str(top5*100) + ' %')
# Out:
# Top1: 72.39999999999999 %
# Top3: 87.6 %
# Top5: 91.2 %

# %%
path_train_loss = main_path + 'loss.txt'
exit_path = main_path
draw_vertical = True
is_best_val = False

max_y = 101
min_y = 20
plot_graph_top(path_train_loss,exit_path, max_y, min_y, draw_vertical, is_best_val)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# valtop: 75.4
# 96
# lowestloss: 70.0
# 20

# %%
path_train_loss = main_path + 'loss.txt'
exit_path = main_path
draw_vertical = True
is_best_val = False

max_y = 4
min_y = 0
plot_graph_loss(path_train_loss, exit_path, max_y, min_y, draw_vertical, is_best_val)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
